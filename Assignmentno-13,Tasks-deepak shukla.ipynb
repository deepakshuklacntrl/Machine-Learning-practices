# %% [markdown]
# ### PART 1 - Data Gathering(Multiple Sources)
# ## Task-1:- Load Data from CSV

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df=pd.read_csv('International_Education_Costs.csv')
df
# Out:
#           Country        City                      University  \
# 0             USA   Cambridge              Harvard University
# 1              UK      London         Imperial College London
# 2          Canada     Toronto           University of Toronto
# 3       Australia   Melbourne         University of Melbourne
# 4         Germany      Munich  Technical University of Munich
# ..            ...         ...                             ...
# 902        France  Strasbourg        University of Strasbourg
# 903      Malaysia       Nilai                            USIM
# 904  Saudi Arabia     Al-Ahsa          King Faisal University
# 905           USA     Seattle        University of Washington
# 906            UK  Nottingham        University of Nottingham
#
#                     Program     Level  Duration_Years  Tuition_USD  \
# 0          Computer Science    Master             2.0        55400
# 1              Data Science    Master             1.0        41200
# ...

# %%
df.shape
# Out:
# (907, 12)

# %%
df.columns
# Out:
# Index(['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years',
#        'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD',
#        'Insurance_USD', 'Exchange_Rate'],
#       dtype='str')

# %%
df.head(6)
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
# 5      Japan      Tokyo             University of Tokyo
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
# 5     Information Science  Master             2.0         8900
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# ...

# %%
df.tail()
# Out:
#           Country        City                University               Program  \
# 902        France  Strasbourg  University of Strasbourg        Data Analytics
# 903      Malaysia       Nilai                      USIM      Computer Science
# 904  Saudi Arabia     Al-Ahsa    King Faisal University   Information Systems
# 905           USA     Seattle  University of Washington  Software Development
# 906            UK  Nottingham  University of Nottingham      Data Engineering
#
#         Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 902    Master             2.0         4000               70.2      1000
# 903  Bachelor             3.0         6800               50.5       400
# 904    Master             2.0         4200               64.2       600
# 905       PhD             5.0        50000               77.8      2000
# 906    Master             2.0        34000               61.2       800
#
#      Visa_Fee_USD  Insurance_USD  Exchange_Rate
# ...

# %%
df.sample(10)
# Out:
#        Country          City                   University  \
# 690    Romania     Bucharest       University Politehnica
# 375  Australia        Hobart       University of Tasmania
# 413         UK        Oxford         University of Oxford
# 325     Canada       Moncton  University of New Brunswick
# 801    Bahrain      Muharraq   Applied Science University
# 599     Greece        Rhodes     University of the Aegean
# 799    Ecuador        Ambato          Universidad Tecnica
# 214        USA      Stanford          Stanford University
# 574     Greece  Thessaloniki         Aristotle University
# 73   Australia    Gold Coast          Griffith University
#
#                     Program     Level  Duration_Years  Tuition_USD  \
# 690    Computer Engineering  Bachelor             3.0         2500
# 375        Computer Science       PhD             4.0        28800
# 413        Computer Science       PhD             4.0        40000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int64
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int64
#  9   Visa_Fee_USD       907 non-null    int64
#  10  Insurance_USD      907 non-null    int64
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int64(4), str(5)
# memory usage: 135.6 KB

# %%
df.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# ...

# %%
df.dtypes
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
df.value_counts()
# Out:
# Country       City        University                      Program                 Level     Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# USA           Cambridge   Harvard University              Computer Science        Master    2.0             55400        83.5               2200      160           1500           1.00             1
# UK            London      Imperial College London         Data Science            Master    1.0             41200        75.8               1800      485           800            0.79             1
# Canada        Toronto     University of Toronto           Business Analytics      Master    2.0             38500        72.5               1600      235           900            1.35             1
# Australia     Melbourne   University of Melbourne         Engineering             Master    2.0             42000        71.2               1400      450           650            1.52             1
# ...

# %% [markdown]
# ### Different parameter
# ## 1- Sep(seperation)

# %%
pd.read_csv('International_Education_Costs.csv',sep=',')
# Out:
#           Country        City                      University  \
# 0             USA   Cambridge              Harvard University
# 1              UK      London         Imperial College London
# 2          Canada     Toronto           University of Toronto
# 3       Australia   Melbourne         University of Melbourne
# 4         Germany      Munich  Technical University of Munich
# ..            ...         ...                             ...
# 902        France  Strasbourg        University of Strasbourg
# 903      Malaysia       Nilai                            USIM
# 904  Saudi Arabia     Al-Ahsa          King Faisal University
# 905           USA     Seattle        University of Washington
# 906            UK  Nottingham        University of Nottingham
#
#                     Program     Level  Duration_Years  Tuition_USD  \
# 0          Computer Science    Master             2.0        55400
# 1              Data Science    Master             1.0        41200
# ...

# %% [markdown]
# ## 2. Names--->

# %%
df = pd.read_csv('International_Education_Costs.csv',names=['Country','Cities','University','Program','Level','Duration_Years','Tuition','Living_Cost','Rent','Visa_Fee','Insurance','Exchange_Rate'])
df
# Out:
#           Country      Cities                University               Program  \
# 0         Country        City                University               Program
# 1             USA   Cambridge        Harvard University      Computer Science
# 2              UK      London   Imperial College London          Data Science
# 3          Canada     Toronto     University of Toronto    Business Analytics
# 4       Australia   Melbourne   University of Melbourne           Engineering
# ..            ...         ...                       ...                   ...
# 903        France  Strasbourg  University of Strasbourg        Data Analytics
# 904      Malaysia       Nilai                      USIM      Computer Science
# 905  Saudi Arabia     Al-Ahsa    King Faisal University   Information Systems
# 906           USA     Seattle  University of Washington  Software Development
# 907            UK  Nottingham  University of Nottingham      Data Engineering
#
# ...

# %% [markdown]
# ## 3. Indexcol

# %%
pd.read_csv('International_Education_Costs.csv',index_col='Country')
# Out:
#                     City                      University  \
# Country
# USA            Cambridge              Harvard University
# UK                London         Imperial College London
# Canada           Toronto           University of Toronto
# Australia      Melbourne         University of Melbourne
# Germany           Munich  Technical University of Munich
# ...                  ...                             ...
# France        Strasbourg        University of Strasbourg
# Malaysia           Nilai                            USIM
# Saudi Arabia     Al-Ahsa          King Faisal University
# USA              Seattle        University of Washington
# UK            Nottingham        University of Nottingham
#
#                              Program     Level  Duration_Years  Tuition_USD  \
# Country
# USA                 Computer Science    Master             2.0        55400
# UK                      Data Science    Master             1.0        41200
# ...

# %% [markdown]
# # 4.Usecols

# %%
pd.read_csv('International_Education_Costs.csv',usecols=['Country','City','University','Program','Level','Duration_Years','Tuition_USD','Living_Cost_Index','Rent_USD','Visa_Fee_USD','Insurance_USD'])
# Out:
#           Country        City                      University  \
# 0             USA   Cambridge              Harvard University
# 1              UK      London         Imperial College London
# 2          Canada     Toronto           University of Toronto
# 3       Australia   Melbourne         University of Melbourne
# 4         Germany      Munich  Technical University of Munich
# ..            ...         ...                             ...
# 902        France  Strasbourg        University of Strasbourg
# 903      Malaysia       Nilai                            USIM
# 904  Saudi Arabia     Al-Ahsa          King Faisal University
# 905           USA     Seattle        University of Washington
# 906            UK  Nottingham        University of Nottingham
#
#                     Program     Level  Duration_Years  Tuition_USD  \
# 0          Computer Science    Master             2.0        55400
# 1              Data Science    Master             1.0        41200
# ...

# %% [markdown]
# # 5.Squeeze----->(combination of usecols and squeeze=True)

# %%
pd.read_csv('International_Education_Costs.csv',usecols=['Level']).squeeze()
# Out:
# 0        Master
# 1        Master
# 2        Master
# 3        Master
# 4        Master
#          ...
# 902      Master
# 903    Bachelor
# 904      Master
# 905         PhD
# 906      Master
# Name: Level, Length: 907, dtype: str

# %% [markdown]
# # 6.nrows

# %%
pd.read_csv('International_Education_Costs.csv',nrows=600)
# Out:
#        Country        City                       University  \
# 0          USA   Cambridge               Harvard University
# 1           UK      London          Imperial College London
# 2       Canada     Toronto            University of Toronto
# 3    Australia   Melbourne          University of Melbourne
# 4      Germany      Munich   Technical University of Munich
# ..         ...         ...                              ...
# 595    Austria  Klagenfurt         University of Klagenfurt
# 596     Mexico      Merida  Universidad Autonoma de Yucatan
# 597      Spain    Zaragoza           University of Zaragoza
# 598      Italy        Pisa               University of Pisa
# 599     Greece      Rhodes         University of the Aegean
#
#                     Program   Level  Duration_Years  Tuition_USD  \
# 0          Computer Science  Master             2.0        55400
# 1              Data Science  Master             1.0        41200
# ...

# %% [markdown]
# # 7.Encoding Parameter(Utf-8)

# %%
pd.read_csv('International_Education_Costs.csv',encoding='latin-1')
# Out:
#           Country        City                      University  \
# 0             USA   Cambridge              Harvard University
# 1              UK      London         Imperial College London
# 2          Canada     Toronto           University of Toronto
# 3       Australia   Melbourne         University of Melbourne
# 4         Germany      Munich  Technical University of Munich
# ..            ...         ...                             ...
# 902        France  Strasbourg        University of Strasbourg
# 903      Malaysia       Nilai                            USIM
# 904  Saudi Arabia     Al-Ahsa          King Faisal University
# 905           USA     Seattle        University of Washington
# 906            UK  Nottingham        University of Nottingham
#
#                     Program     Level  Duration_Years  Tuition_USD  \
# 0          Computer Science    Master             2.0        55400
# 1              Data Science    Master             1.0        41200
# ...

# %% [markdown]
# # 8.Skip bad lines(error_bad_lines)

# %%
'''pd.read_csv('International_Education_Costs.csv',error_bad_lines=False)'''
# Out:
# "pd.read_csv('International_Education_Costs.csv',error_bad_lines=False)"

# %% [markdown]
# ## Task-2:-> Load data from JSON

# %%
import pandas as pd

# %%
pd.read_json('iris.json')
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
json=pd.read_json('iris.json')

# %%
print(json)
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Task-3:- Load data from SQL Database

# %%
pip install mysql.connector
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
data=mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
df=pd.read_sql_query('select * from city',data)
df
# Out:
# C:\Users\Deepak Shukla\AppData\Local\Temp\ipykernel_7120\1022638143.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query('select * from city',data)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# ...

# %%
df=pd.read_sql_query('select * from city where Countrycode like "IND"',data)
df
# Out:
# C:\Users\Deepak Shukla\AppData\Local\Temp\ipykernel_7120\818410307.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query('select * from city where Countrycode like "IND"',data)
#        ID                Name CountryCode        District  Population
# 0    1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1    1025               Delhi         IND           Delhi     7206704
# 2    1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 3    1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 4    1028           Hyderabad         IND  Andhra Pradesh     2964638
# ..    ...                 ...         ...             ...         ...
# 336  1360        Ambala Sadar         IND         Haryana       90712
# ...

# %%
df=pd.read_sql_query('select * from country',data)
df
# Out:
# C:\Users\Deepak Shukla\AppData\Local\Temp\ipykernel_7120\3463115028.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query('select * from country',data)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %%
df=pd.read_sql_query('select * from country where lifeexpectancy >80',data)
df
# Out:
# C:\Users\Deepak Shukla\AppData\Local\Temp\ipykernel_7120\631380420.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query('select * from country where lifeexpectancy >80',data)
#   Code        Name Continent           Region  SurfaceArea  IndepYear  \
# 0  AND     Andorra    Europe  Southern Europe        468.0     1278.0
# 1  JPN       Japan      Asia     Eastern Asia     377829.0     -660.0
# 2  MAC       Macao      Asia     Eastern Asia         18.0        NaN
# 3  SGP   Singapore      Asia   Southeast Asia        618.0     1965.0
# 4  SMR  San Marino    Europe  Southern Europe         61.0      885.0
#
#    Population  LifeExpectancy        GNP     GNPOld  \
# 0       78000            83.5     1630.0        NaN
# 1   126714000            80.7  3787042.0  4192638.0
# ...

# %% [markdown]
# ### Task-4:- API mini project(TMDB API)
# # Mini project:movie Data Collector

# %%
from urllib import response

import requests


url = 'https://imdb236.p.rapidapi.com/api/imdb/cast/nm0000190/titles'

headers = {
    'accept': 'application/json',
    'x-rapidapi-host': 'imdb236.p.rapidapi.com',
    'x-rapidapi-key': 'ad3064411cmsh3c1f5540e1efd0dp1506d9jsn5e0c0018e6d7'
}

response=requests.get(url=url,headers=headers)

print(response)

response.json()
# Out:
# <Response [403]>
# {'message': 'You are not subscribed to this API.'}

# %% [markdown]
# # so, i have tried opening imdb site,but it didn't responde, so tried rapid api,and it showes this response,[403.]

# %% [markdown]
# ### PART-2- Datapreprocessing & Cleaning(kaggle Dataset)
# # Task-5:-
# ## Understanding the Data

# %%
df=pd.read_csv('International_Education_Costs.csv')
df
# Out:
#           Country        City                      University  \
# 0             USA   Cambridge              Harvard University
# 1              UK      London         Imperial College London
# 2          Canada     Toronto           University of Toronto
# 3       Australia   Melbourne         University of Melbourne
# 4         Germany      Munich  Technical University of Munich
# ..            ...         ...                             ...
# 902        France  Strasbourg        University of Strasbourg
# 903      Malaysia       Nilai                            USIM
# 904  Saudi Arabia     Al-Ahsa          King Faisal University
# 905           USA     Seattle        University of Washington
# 906            UK  Nottingham        University of Nottingham
#
#                     Program     Level  Duration_Years  Tuition_USD  \
# 0          Computer Science    Master             2.0        55400
# 1              Data Science    Master             1.0        41200
# ...

# %%
df.tail()
# Out:
#           Country        City                University               Program  \
# 902        France  Strasbourg  University of Strasbourg        Data Analytics
# 903      Malaysia       Nilai                      USIM      Computer Science
# 904  Saudi Arabia     Al-Ahsa    King Faisal University   Information Systems
# 905           USA     Seattle  University of Washington  Software Development
# 906            UK  Nottingham  University of Nottingham      Data Engineering
#
#         Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 902    Master             2.0         4000               70.2      1000
# 903  Bachelor             3.0         6800               50.5       400
# 904    Master             2.0         4200               64.2       600
# 905       PhD             5.0        50000               77.8      2000
# 906    Master             2.0        34000               61.2       800
#
#      Visa_Fee_USD  Insurance_USD  Exchange_Rate
# ...

# %%
df.sample(5)
# Out:
#      Country      City               University                  Program  \
# 307   Canada  Victoria   University of Victoria         Computer Science
# 303   Canada    London       Western University         Computer Science
# 851    Spain    Madrid  Universidad Politecnica     Software Engineering
# 900    Spain  Zaragoza   University of Zaragoza  Artificial Intelligence
# 439  Germany      Bonn       University of Bonn              Engineering
#
#       Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 307  Master             2.0        22900               64.8      1400
# 303  Master             2.0        23500               61.5      1200
# 851     PhD             4.0         3500               71.4      1100
# 900     PhD             4.0         2900               63.2       650
# 439  Master             2.0            0               67.8      1100
#
#      Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 307           235            600           1.35
# ...

# %%
df.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int64
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int64
#  9   Visa_Fee_USD       907 non-null    int64
#  10  Insurance_USD      907 non-null    int64
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int64(4), str(5)
# memory usage: 135.6 KB

# %%
df.size
# Out:
# 10884

# %%
df.shape
# Out:
# (907, 12)

# %%
df.dtypes
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
df['Country'].value_counts()
# Out:
# Country
# UK                93
# Australia         86
# USA               78
# Canada            76
# Germany           33
#                   ..
# Taiwan             1
# Czech Republic     1
# South Africa       1
# Nigeria            1
# Vietnam            1
# Name: count, Length: 71, dtype: int64

# %%
df['Country'].unique()
# Out:
# <ArrowStringArray>
# [               'USA',                 'UK',             'Canada',
#           'Australia',            'Germany',              'Japan',
#         'Netherlands',          'Singapore',             'France',
#         'Switzerland',             'Sweden',            'Denmark',
#               'China',        'South Korea',            'Ireland',
#         'New Zealand',            'Austria',            'Belgium',
#           'Hong Kong',           'Portugal',             'Israel',
#              'Taiwan',     'Czech Republic',              'India',
#              'Poland',           'Malaysia',              'Spain',
#               'Italy',            'Finland',             'Norway',
#              'Brazil',             'Turkey',             'Russia',
#              'Mexico',             'Greece',           'Thailand',
#                 'UAE',       'South Africa',              'Egypt',
#           'Argentina',          'Indonesia',       'Saudi Arabia',
# ...

# %%
df[df['Country']=='India']
# Out:
#     Country       City                   University                  Program  \
# 44    India  Bangalore  Indian Institute of Science         Computer Science
# 648   India  Bangalore  Indian Institute of Science             Data Science
# 654   India     Mumbai                   IIT Bombay     Computer Engineering
# 659   India      Delhi                    IIT Delhi  Artificial Intelligence
# 665   India    Chennai                   IIT Madras     Software Engineering
# 671   India  Hyderabad                IIT Hyderabad           Data Analytics
# 677   India       Pune                     IIT Pune         Computer Science
# 683   India     Kanpur                   IIT Kanpur  Artificial Intelligence
#
#       Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 44   Master             2.0         2500               45.6       500
# 648     PhD             4.0         2000               45.2       300
# ...

# %%
df.columns
# Out:
# Index(['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years',
#        'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD',
#        'Insurance_USD', 'Exchange_Rate'],
#       dtype='str')

# %%
df['City'].value_counts()
# Out:
# City
# Singapore    18
# Melbourne    11
# Sydney       11
# London       10
# Canberra      8
#              ..
# Tabuk         1
# Shah Alam     1
# Makkah        1
# Nilai         1
# Al-Ahsa       1
# Name: count, Length: 556, dtype: int64

# %%
df['Program'].value_counts()
# Out:
# Program
# Computer Science           312
# Data Science                82
# Computer Engineering        71
# Software Engineering        57
# Artificial Intelligence     53
#                           ...
# Electronics                  1
# Electronic Engineering       1
# Digital Design               1
# Digital Business             1
# Data Systems                 1
# Name: count, Length: 92, dtype: int64

# %%
df['Level'].value_counts()
# Out:
# Level
# Master      451
# Bachelor    297
# PhD         159
# Name: count, dtype: int64

# %%
df['Duration_Years'].value_counts()
# Out:
# Duration_Years
# 2.0    423
# 4.0    276
# 3.0    171
# 5.0     17
# 1.0     16
# 2.5      3
# 1.5      1
# Name: count, dtype: int64

# %% [markdown]
# ## Task 6:- Data Cleaning

# %%
df.isnull().sum()
# Out:
# Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64

# %%
df['Duration_Years'].value_counts()
# Out:
# Duration_Years
# 2.0    423
# 4.0    276
# 3.0    171
# 5.0     17
# 1.0     16
# 2.5      3
# 1.5      1
# Name: count, dtype: int64

# %%
df['Duration_Years'].min()
# Out:
# np.float64(1.0)

# %%
df['Duration_Years'].max()
# Out:
# np.float64(5.0)

# %%
df['Duration_Years'].mean()
# Out:
# np.float64(2.8368246968026463)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
df['Country']=df['Country'].astype('object')
df['City']=df['City'].astype('object')
df['University']=df['University'].astype('object')
df['Program']=df['Program'].astype('object')
df['Level']=df['Level'].astype('object')
df['Duration_Years']=df['Duration_Years'].astype('float32')
df['Tuition_USD']=df['Tuition_USD'].astype('int32')
df['Living_Cost_Index']=df['Living_Cost_Index'].astype('float32')
df['Rent_USD']=df['Rent_USD'].astype('int32')
df['Visa_Fee_USD']=df['Visa_Fee_USD'].astype('int32')
df['Insurance_USD']=df['Insurance_USD'].astype('int32')
df['Exchange_Rate']=df['Exchange_Rate'].astype('float64')

# %%
df.dtypes
# Out:
# Country               object
# City                  object
# University            object
# Program               object
# Level                 object
# Duration_Years       float32
# Tuition_USD            int32
# Living_Cost_Index    float32
# Rent_USD               int32
# Visa_Fee_USD           int32
# Insurance_USD          int32
# Exchange_Rate        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    object
#  1   City               907 non-null    object
#  2   University         907 non-null    object
#  3   Program            907 non-null    object
#  4   Level              907 non-null    object
#  5   Duration_Years     907 non-null    float32
#  6   Tuition_USD        907 non-null    int32
#  7   Living_Cost_Index  907 non-null    float32
#  8   Rent_USD           907 non-null    int32
#  9   Visa_Fee_USD       907 non-null    int32
#  10  Insurance_USD      907 non-null    int32
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float32(2), float64(1), int32(4), object(5)
# memory usage: 63.9+ KB

# %% [markdown]
# ### PART 3 - Exploraory Data Analysis(EDA)
# ## Task-8:- Univariate Analysis
# # (histogram + KDE)

# %%
df['Duration_Years'].value_counts()
# Out:
# Duration_Years
# 2.0    423
# 4.0    276
# 3.0    171
# 5.0     17
# 1.0     16
# 2.5      3
# 1.5      1
# Name: count, dtype: int64

# %%
d1=df[df['Level']=='Masters'].head(150)
d2=df[df['Level']=='Bachelors'].head(150)
d3=df[df['Level']=='PhD'].head(150)
d4=pd.concat([d1,d2,d3])
d4.shape
# Out:
# (150, 12)

# %%
sns.histplot(data=d4,x='Duration_Years')
plt.show()

# %%
sns.histplot(data=df,x='Tuition_USD',kde=True)
plt.show()

# %% [markdown]
# # 2.Count plot

# %%
sns.countplot(data=df,x='Level')
plt.show()

# %% [markdown]
# # 3.outliers(Box plot)

# %%
sns.boxplot(data=df,x='Rent_USD')
plt.show()

# %%
sns.kdeplot(data=df,x='Tuition_USD')
plt.grid()

# %%
sns.histplot(data=df,x='Rent_USD')
plt.show()

# %%
country=df[df['Country'].isin(['UK','Australia','USA','Canada','Germany','Taiwan','Czech Republic','South Africa','Nigeria','Vietnam'])]

# %%
sns.countplot(data=country, x='Country')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## Task-9:-
# # Bivariate Analysis

# %% [markdown]
# # 1.Numerical vs Numerical

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    object
#  1   City               907 non-null    object
#  2   University         907 non-null    object
#  3   Program            907 non-null    object
#  4   Level              907 non-null    object
#  5   Duration_Years     907 non-null    float32
#  6   Tuition_USD        907 non-null    int32
#  7   Living_Cost_Index  907 non-null    float32
#  8   Rent_USD           907 non-null    int32
#  9   Visa_Fee_USD       907 non-null    int32
#  10  Insurance_USD      907 non-null    int32
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float32(2), float64(1), int32(4), object(5)
# memory usage: 63.9+ KB

# %%
sns.scatterplot(data=df,x='Duration_Years',y='Tuition_USD')
plt.show()

# %%
university=country[country['University'].isin(['University of Washington', 'University of Melbourne', 'Stanford University', 'Australian National University', 'University of Sydney', 'University of Adelaide', 'University of Western Australia', 'Griffith University', 'University of Tasmania', 'University of Newcastle'])]

# %%
data=university.pivot_table(index='Country',columns='Rent_USD',values='Tuition_USD',aggfunc='mean')
sns.heatmap(data)
plt.show()

# %% [markdown]
# ## 2.Categorical vs Numerical
# # Bar plot

# %%
sns.barplot(data=country,x='Country',y='Tuition_USD')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # Box plot

# %%
sns.boxplot(data=country,x='Country',y='Tuition_USD')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(data=country,x='Country',y='Visa_Fee_USD')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.lineplot(data=university,x='University',y='Duration_Years')
plt.xticks(rotation= 45)
plt.grid()
plt.show()

# %% [markdown]
# ## Task-7:-
# # Feature preparation(Basic)
# # 1.conversion(categorical into Numerical)----> Label Encoding

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0          83.500000      2200           160           1500           1.00
# 1          75.800003      1800           485            800           0.79
# ...

# %%
df['Total_Cost']= df['Tuition_USD'] + df['Rent_USD']
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate  \
# 0          83.500000      2200           160           1500           1.00
# 1          75.800003      1800           485            800           0.79
# ...

# %%
df=df[['Country','City','University','Program','Level','Duration_Years','Living_Cost_Index','Visa_Fee_USD','Insurance_USD','Total_Cost']]
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Living_Cost_Index  \
# 0        Computer Science  Master             2.0          83.500000
# 1            Data Science  Master             1.0          75.800003
# 2      Business Analytics  Master             2.0          72.500000
# 3             Engineering  Master             2.0          71.199997
# 4  Mechanical Engineering  Master             2.0          70.500000
#
#    Visa_Fee_USD  Insurance_USD  Total_Cost
# 0           160           1500       57600
# 1           485            800       43000
# 2           235            900       40100
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Country']=le.fit_transform(df['Country'])
df['City']=le.fit_transform(df['City'])
df['University']=le.fit_transform(df['University'])
df['Program']=le.fit_transform(df['Program'])
df['Level']=le.fit_transform(df['Level'])

# %%
df.head()
# Out:
#    Country  City  University  Program  Level  Duration_Years  \
# 0       66    84         101       17      1             2.0
# 1       65   283         128       27      1             1.0
# 2        9   503         572        9      1             2.0
# 3        2   313         495       44      1             2.0
# 4       22   330         307       66      1             2.0
#
#    Living_Cost_Index  Visa_Fee_USD  Insurance_USD  Total_Cost
# 0          83.500000           160           1500       57600
# 1          75.800003           485            800       43000
# 2          72.500000           235            900       40100
# 3          71.199997           450            650       43400
# 4          70.500000            75            550        1600

# %% [markdown]
# # 2. Separate features & Target column

# %%
x=df.iloc[:,:9]
y=df['Total_Cost']

# %%
x
# Out:
#      Country  City  University  Program  Level  Duration_Years  \
# 0         66    84         101       17      1             2.0
# 1         65   283         128       27      1             1.0
# 2          9   503         572        9      1             2.0
# 3          2   313         495       44      1             2.0
# 4         22   330         307       66      1             2.0
# ..       ...   ...         ...      ...    ...             ...
# 902       21   469         556       25      1             2.0
# 903       38   344         345       17      0             3.0
# 904       51    12         154       57      1             2.0
# 905       66   441         585       84      2             5.0
# 906       65   347         512       26      1             2.0
#
#      Living_Cost_Index  Visa_Fee_USD  Insurance_USD
# 0            83.500000           160           1500
# 1            75.800003           485            800
# ...

# %%
y
# Out:
# 0      57600
# 1      43000
# 2      40100
# 3      43400
# 4       1600
#        ...
# 902     5000
# 903     7200
# 904     4800
# 905    52000
# 906    34800
# Name: Total_Cost, Length: 907, dtype: int32

# %% [markdown]
# ## Task-10:-
# # Insights & Observation
